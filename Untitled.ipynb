# %%
from dotenv import load_dotenv
import os
import pandas as pd
import hvplot.pandas

load_dotenv()
from fredapi import Fred

api_key = os.getenv("FRED_API_KEY")
type(api_key)

fred = Fred(api_key=api_key)

WALCL = fred.get_series('WALCL')
CPIAUCSL = fred.get_series('CPIAUCSL')
FEDFUNDS = fred.get_series('FEDFUNDS')
liquid = fred.get_series('BOGZ1FL104001005Q')

# %%
output_data_file = 'WALCL.csv'
WALCL.to_csv(output_data_file)

# %%
output_data_file = 'CPIAUCSL.csv'
CPIAUCSL.to_csv(output_data_file)

# %%
output_data_file = 'FEDFUNDS.csv'
FEDFUNDS.to_csv(output_data_file)

# %%
output_data_file = 'liquid.csv'
liquid.to_csv(output_data_file)

# %%
WALCL = WALCL.to_frame().reset_index()

WALCL = WALCL.rename(columns = {'index' : 'date',
                       'O' : 'WALCL'})
WALCL
# Out:
#            date          0
# 0    2002-12-18   719542.0
# 1    2002-12-25   732059.0
# 2    2003-01-01   730994.0
# 3    2003-01-08   723762.0
# 4    2003-01-15   720074.0
# ...         ...        ...
# 1071 2023-06-28  8340914.0
# 1072 2023-07-05  8298312.0
# 1073 2023-07-12  8296923.0
# 1074 2023-07-19  8274552.0
# 1075 2023-07-26  8243344.0
#
# [1076 rows x 2 columns]

# %%
CPIAUCSL = CPIAUCSL.to_frame().reset_index()

CPIAUCSL = CPIAUCSL.rename(columns = {'index' : 'date',
                       0 : 'CPIAUCSL'})
CPIAUCSL
# Out:
#           date  CPIAUCSL
# 0   1947-01-01    21.480
# 1   1947-02-01    21.620
# 2   1947-03-01    22.000
# 3   1947-04-01    22.000
# 4   1947-05-01    21.950
# ..         ...       ...
# 913 2023-02-01   301.648
# 914 2023-03-01   301.808
# 915 2023-04-01   302.918
# 916 2023-05-01   303.294
# 917 2023-06-01   303.841
#
# [918 rows x 2 columns]

# %%
FEDFUNDS = FEDFUNDS.to_frame().reset_index()

FEDFUNDS = FEDFUNDS.rename(columns = {'index' : 'date',
                       0 : 'FEDFUNDS'})
FEDFUNDS
# Out:
#           date  FEDFUNDS
# 0   1954-07-01      0.80
# 1   1954-08-01      1.22
# 2   1954-09-01      1.07
# 3   1954-10-01      0.85
# 4   1954-11-01      0.83
# ..         ...       ...
# 823 2023-02-01      4.57
# 824 2023-03-01      4.65
# 825 2023-04-01      4.83
# 826 2023-05-01      5.06
# 827 2023-06-01      5.08
#
# [828 rows x 2 columns]

# %%
#liquid =liquid.to_frame().reset_index()

liquid = liquid.rename(columns = {'index' : 'date',
                       0 : 'liquid'})
liquid
# Out:
#           date     liquid
# 0   1945-10-01    38652.0
# 1   1946-01-01        NaN
# 2   1946-04-01        NaN
# 3   1946-07-01        NaN
# 4   1946-10-01    33594.0
# ..         ...        ...
# 305 2022-01-01  6935871.0
# 306 2022-04-01  6189642.0
# 307 2022-07-01  6006974.0
# 308 2022-10-01  6324169.0
# 309 2023-01-01  6498217.0
#
# [310 rows x 2 columns]

# %%
output_data_file = 'liquid.csv'
liquid.to_csv(output_data_file)

# %%
liquid['date'] = pd.to_datetime(liquid['date'])

# %%
liquid.plot()
# Out:
# Bad key text.latex.preview in file /Users/jim/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 123 ('text.latex.preview : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key mathtext.fallback_to_cm in file /Users/jim/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 155 ('mathtext.fallback_to_cm : True  # When True, use symbols from the Computer Modern')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# ...
